# %%
import pandas as pd

# %%
bem_df =pd.read_csv('BEML.csv')

# %%
gla_df=pd.read_csv('GLAXO.csv')

# %%
bem_df.head()
# Out:
#          Date    Open     High      Low    Last    Close  \
# 0  2010-01-04  1121.0  1151.00  1121.00  1134.0  1135.60
# 1  2010-01-05  1146.8  1149.00  1128.75  1135.0  1134.60
# 2  2010-01-06  1140.0  1164.25  1130.05  1137.0  1139.60
# 3  2010-01-07  1142.0  1159.40  1119.20  1141.0  1144.15
# 4  2010-01-08  1156.0  1172.00  1140.00  1141.2  1144.05
#
#    Total Trade Quantity  Turnover (Lacs)
# 0              101651.0          1157.18
# 1               59504.0           676.47
# 2              128908.0          1482.84
# 3              117871.0          1352.98
# 4              170063.0          1971.42

# %%
bem_df = bem_df[['Date','Close']]
bem_df
# Out:
#             Date    Close
# 0     2010-01-04  1135.60
# 1     2010-01-05  1134.60
# 2     2010-01-06  1139.60
# 3     2010-01-07  1144.15
# 4     2010-01-08  1144.05
# ...          ...      ...
# 1734  2016-12-26   950.25
# 1735  2016-12-27   975.70
# 1736  2016-12-28   974.40
# 1737  2016-12-29   986.05
# 1738  2016-12-30  1000.60
#
# [1739 rows x 2 columns]

# %%
gla_df.head()
# Out:
#          Date     Open     High      Low    Last    Close  \
# 0  2010-01-04  1613.00  1629.10  1602.00  1629.0  1625.65
# 1  2010-01-05  1639.95  1639.95  1611.05  1620.0  1616.80
# 2  2010-01-06  1618.00  1644.00  1617.00  1639.0  1638.50
# 3  2010-01-07  1645.00  1654.00  1636.00  1648.0  1648.70
# 4  2010-01-08  1650.00  1650.00  1626.55  1640.0  1639.80
#
#    Total Trade Quantity  Turnover (Lacs)
# 0                9365.0           151.74
# 1               38148.0           622.58
# 2               36519.0           595.09
# 3               12809.0           211.00
# 4               28035.0           459.11

# %%
gla_df = gla_df[['Date','Close']]
gla_df
# Out:
#             Date    Close
# 0     2010-01-04  1625.65
# 1     2010-01-05  1616.80
# 2     2010-01-06  1638.50
# 3     2010-01-07  1648.70
# 4     2010-01-08  1639.80
# ...          ...      ...
# 1734  2016-12-26  2723.50
# 1735  2016-12-27  2701.75
# 1736  2016-12-28  2702.15
# 1737  2016-12-29  2727.90
# 1738  2016-12-30  2729.80
#
# [1739 rows x 2 columns]

# %%
bem_df['Gain'] = bem_df['Close'].pct_change(periods = 1)
gla_df['Gain'] = gla_df['Close'].pct_change(periods = 1)

# %%
bem_df
gla_df
# Out:
#             Date    Close      Gain
# 0     2010-01-04  1625.65       NaN
# 1     2010-01-05  1616.80 -0.005444
# 2     2010-01-06  1638.50  0.013422
# 3     2010-01-07  1648.70  0.006225
# 4     2010-01-08  1639.80 -0.005398
# ...          ...      ...       ...
# 1734  2016-12-26  2723.50 -0.001283
# 1735  2016-12-27  2701.75 -0.007986
# 1736  2016-12-28  2702.15  0.000148
# 1737  2016-12-29  2727.90  0.009529
# 1738  2016-12-30  2729.80  0.000697
#
# [1739 rows x 3 columns]

# %%
bem_df.isna().sum()
# Out:
# Date     0
# Close    0
# Gain     1
# dtype: int64

# %%
gla_df.isna().sum()
# Out:
# Date     0
# Close    0
# Gain     1
# dtype: int64

# %%
bem_df = bem_df.dropna()
gla_df = gla_df.dropna()

# %%
gla_df = gla_df.set_index(pd.DatetimeIndex(gla_df['Date']))
bem_df = bem_df.set_index(pd.DatetimeIndex(bem_df['Date']))

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize = (10,5))
plt.plot(bem_df.index,bem_df.Close)
plt.xlabel('Time')
plt.ylabel('Close')
plt.show()

# %%
plt.figure(figsize = (10,5))
plt.plot(gla_df.index,gla_df.Close)
plt.xlabel('Time')
plt.ylabel('Close')
plt.show()

# %%
plt.figure(figsize = (10,5))
plt.plot(gla_df.index,gla_df.Close)
plt.plot(bem_df.index,bem_df.Close)
plt.xlabel('Time')
plt.ylabel('Close')
plt.show()

# %%
plt.figure(figsize= (10,5))
plt.plot(bem_df['Gain'])
plt.xlabel('Time')
plt.ylabel('Gain')
plt.show()

# %%
sns.distplot(gla_df.Gain, label = 'Glaxo');
plt.xlabel('gain');
plt.ylabel('Density');
plt.legend();
# Out:
# C:\Users\ygred\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.displot(bem_df.Gain,label = 'Gain');
plt.xlabel('Time');
plt.ylabel('Desinity');
plt.legend();

# %%
sns.distplot(bem_df.Gain, label = 'BEML');
plt.xlabel('gain');
plt.ylabel('Density');
plt.legend();
# Out:
# C:\Users\ygred\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print(bem_df['Gain'].mean()*100)
print(bem_df['Gain'].std())
# Out:
# 0.027074807905723152
# 0.02643083146847487

# %%
print(gla_df['Gain'].mean()*100)
print(gla_df['Gain'].std())
# Out:
# 0.038604108259229164
# 0.013360538552253333

# %%
from scipy.stats import norm
nobem = norm(bem_df['Gain'].mean(),bem_df['Gain'].std())

# %%
nogla = norm(gla_df['Gain'].mean(),gla_df['Gain'].std())

# %%
# probability making 2 % loss  or higher
nobem.cdf(-0.02)
# Out:
# 0.22155987503755292

# %%
# probability making 2 % loss or higher loss in glaxo 
1-nogla.cdf(-0.02)
# Out:
# 0.9364751133282261

# %%
1-nogla.cdf(0.02)
# Out:
# 0.07104511457618568
